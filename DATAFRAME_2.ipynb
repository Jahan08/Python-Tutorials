# %% [markdown]
# # DATAFRAME NEW THING

# %%
import pandas as pd
from pandas import DataFrame, Series

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Class    Type
# 0           5.1          3.5           1.4          0.2      0  Setosa
# 1           4.9          3.0           1.4          0.2      0  Setosa
# 2           4.7          3.2           1.3          0.2      0  Setosa
# 3           4.6          3.1           1.5          0.2      0  Setosa
# 4           5.0          3.6           1.4          0.2      0  Setosa

# %%
df.columns
# Out:
# Index(['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width', 'Class',
#        'Type'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=150, step=1),
#  Index(['Sepal_length', 'Sepal_width', 'Petal_length', 'Petal_width', 'Class',
#         'Type'],
#        dtype='object')]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Sepal_length  Sepal_width  Petal_length  Petal_width  Class       Type
# 0             5.1          3.5           1.4          0.2      0     Setosa
# 1             4.9          3.0           1.4          0.2      0     Setosa
# 2             4.7          3.2           1.3          0.2      0     Setosa
# 3             4.6          3.1           1.5          0.2      0     Setosa
# 4             5.0          3.6           1.4          0.2      0     Setosa
# ..            ...          ...           ...          ...    ...        ...
# 145           6.7          3.0           5.2          2.3      2  Virginica
# 146           6.3          2.5           5.0          1.9      2  Virginica
# 147           6.5          3.0           5.2          2.0      2  Virginica
# 148           6.2          3.4           5.4          2.3      2  Virginica
# 149           5.9          3.0           5.1          1.8      2  Virginica
#
# [150 rows x 6 columns]>

# %% [markdown]
# # extract column

# %%
df.Type
# Out:
# 0         Setosa
# 1         Setosa
# 2         Setosa
# 3         Setosa
# 4         Setosa
#          ...
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: Type, Length: 150, dtype: object

# %%
df.Sepal_length #works when there is no space in the name
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: Sepal_length, Length: 150, dtype: float64

# %%
df["Type"].head()
# Out:
# 0    Setosa
# 1    Setosa
# 2    Setosa
# 3    Setosa
# 4    Setosa
# Name: Type, dtype: object

# %%
type(df["Type"])
# Out:
# pandas.core.series.Series

# %%
df["Type"].tail()
# Out:
# 145    Virginica
# 146    Virginica
# 147    Virginica
# 148    Virginica
# 149    Virginica
# Name: Type, dtype: object

# %%
df[["Sepal_length", "Type"]].head()
# Out:
#    Sepal_length    Type
# 0           5.1  Setosa
# 1           4.9  Setosa
# 2           4.7  Setosa
# 3           4.6  Setosa
# 4           5.0  Setosa

# %%
type(df[["Sepal_length", "Type"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # ADDING NEW COLUMNS

# %%
df["Flowers"] = "ROSE"

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Class    Type Flowers
# 0           5.1          3.5           1.4          0.2      0  Setosa    ROSE
# 1           4.9          3.0           1.4          0.2      0  Setosa    ROSE
# 2           4.7          3.2           1.3          0.2      0  Setosa    ROSE
# 3           4.6          3.1           1.5          0.2      0  Setosa    ROSE
# 4           5.0          3.6           1.4          0.2      0  Setosa    ROSE

# %%
df["Another_flower"] = "IRIS"

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Class    Type  \
# 0           5.1          3.5           1.4          0.2      0  Setosa
# 1           4.9          3.0           1.4          0.2      0  Setosa
# 2           4.7          3.2           1.3          0.2      0  Setosa
# 3           4.6          3.1           1.5          0.2      0  Setosa
# 4           5.0          3.6           1.4          0.2      0  Setosa
#
#   Flowers Another_flower
# 0    ROSE           IRIS
# 1    ROSE           IRIS
# 2    ROSE           IRIS
# 3    ROSE           IRIS
# 4    ROSE           IRIS

# %%
df.insert(3, column= "nothing", value= "no_flowers") #press shift+tab in the bracket

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length     nothing  Petal_width  Class  \
# 0           5.1          3.5           1.4  no_flowers          0.2      0
# 1           4.9          3.0           1.4  no_flowers          0.2      0
# 2           4.7          3.2           1.3  no_flowers          0.2      0
# 3           4.6          3.1           1.5  no_flowers          0.2      0
# 4           5.0          3.6           1.4  no_flowers          0.2      0
#
#      Type Flowers Another_flower
# 0  Setosa    ROSE           IRIS
# 1  Setosa    ROSE           IRIS
# 2  Setosa    ROSE           IRIS
# 3  Setosa    ROSE           IRIS
# 4  Setosa    ROSE           IRIS

# %%
df.insert(8, column= "nothing-1", value= "no_flowers") #press shift+tab in the bracket
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length     nothing  Petal_width  Class  \
# 0           5.1          3.5           1.4  no_flowers          0.2      0
# 1           4.9          3.0           1.4  no_flowers          0.2      0
# 2           4.7          3.2           1.3  no_flowers          0.2      0
# 3           4.6          3.1           1.5  no_flowers          0.2      0
# 4           5.0          3.6           1.4  no_flowers          0.2      0
#
#      Type Flowers   nothing-1 Another_flower
# 0  Setosa    ROSE  no_flowers           IRIS
# 1  Setosa    ROSE  no_flowers           IRIS
# 2  Setosa    ROSE  no_flowers           IRIS
# 3  Setosa    ROSE  no_flowers           IRIS
# 4  Setosa    ROSE  no_flowers           IRIS

# %% [markdown]
# # BROADCASTING OPERATIONS

# %%
df["Sepal_length"].add(5) #want to add to the existing values of the column
# Out:
# 0      10.1
# 1       9.9
# 2       9.7
# 3       9.6
# 4      10.0
#        ...
# 145    11.7
# 146    11.3
# 147    11.5
# 148    11.2
# 149    10.9
# Name: Sepal_length, Length: 150, dtype: float64

# %%
df["Sepal_length"] + 5
# Out:
# 0      10.1
# 1       9.9
# 2       9.7
# 3       9.6
# 4      10.0
#        ...
# 145    11.7
# 146    11.3
# 147    11.5
# 148    11.2
# 149    10.9
# Name: Sepal_length, Length: 150, dtype: float64

# %%
df["Sepal_length"] - 1
# Out:
# 0      4.1
# 1      3.9
# 2      3.7
# 3      3.6
# 4      4.0
#       ...
# 145    5.7
# 146    5.3
# 147    5.5
# 148    5.2
# 149    4.9
# Name: Sepal_length, Length: 150, dtype: float64

# %%
df["Sepal_length"].sub(1)
# Out:
# 0      4.1
# 1      3.9
# 2      3.7
# 3      3.6
# 4      4.0
#       ...
# 145    5.7
# 146    5.3
# 147    5.5
# 148    5.2
# 149    4.9
# Name: Sepal_length, Length: 150, dtype: float64

# %%
#converting the unit
df["Sepal_length"].mul(1000)
df["Sepal_length"] * 1000
# Out:
# 0      5100.0
# 1      4900.0
# 2      4700.0
# 3      4600.0
# 4      5000.0
#         ...
# 145    6700.0
# 146    6300.0
# 147    6500.0
# 148    6200.0
# 149    5900.0
# Name: Sepal_length, Length: 150, dtype: float64

# %%
df["Sepal in Kg"] = df["Sepal_length"] * 1000

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length     nothing  Petal_width  Class  \
# 0           5.1          3.5           1.4  no_flowers          0.2      0
# 1           4.9          3.0           1.4  no_flowers          0.2      0
# 2           4.7          3.2           1.3  no_flowers          0.2      0
# 3           4.6          3.1           1.5  no_flowers          0.2      0
# 4           5.0          3.6           1.4  no_flowers          0.2      0
#
#      Type Flowers   nothing-1 Another_flower  Sepal in Kg
# 0  Setosa    ROSE  no_flowers           IRIS       5100.0
# 1  Setosa    ROSE  no_flowers           IRIS       4900.0
# 2  Setosa    ROSE  no_flowers           IRIS       4700.0
# 3  Setosa    ROSE  no_flowers           IRIS       4600.0
# 4  Setosa    ROSE  no_flowers           IRIS       5000.0

# %%
#div() or /

# %% [markdown]
# # DELETE NAN VALUES

# %%
df1=pd.read_csv('iris.csv')
df1.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Class    Type
# 0           5.1          3.5           1.4          0.2      0  Setosa
# 1           4.9          3.0           1.4          0.2      0  Setosa
# 2           4.7          3.2           1.3          0.2      0  Setosa
# 3           4.6          3.1           1.5          0.2      0  Setosa
# 4           5.0          3.6           1.4          0.2      0  Setosa

# %%
df1["Another_flower"] = "NaN"
df1.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Class    Type  \
# 0           5.1          3.5           1.4          0.2      0  Setosa
# 1           4.9          3.0           1.4          0.2      0  Setosa
# 2           4.7          3.2           1.3          0.2      0  Setosa
# 3           4.6          3.1           1.5          0.2      0  Setosa
# 4           5.0          3.6           1.4          0.2      0  Setosa
#
#   Another_flower
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
df1.dropna()#only delete or drop the row with NAN
df1.dropna(how= "all") #to overwrite the old dataframe inplace=True
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width  Class       Type  \
# 0             5.1          3.5           1.4          0.2      0     Setosa
# 1             4.9          3.0           1.4          0.2      0     Setosa
# 2             4.7          3.2           1.3          0.2      0     Setosa
# 3             4.6          3.1           1.5          0.2      0     Setosa
# 4             5.0          3.6           1.4          0.2      0     Setosa
# ..            ...          ...           ...          ...    ...        ...
# 145           6.7          3.0           5.2          2.3      2  Virginica
# 146           6.3          2.5           5.0          1.9      2  Virginica
# 147           6.5          3.0           5.2          2.0      2  Virginica
# 148           6.2          3.4           5.4          2.3      2  Virginica
# 149           5.9          3.0           5.1          1.8      2  Virginica
#
#     Another_flower
# 0              NaN
# ...

# %%
df1.dropna(axis= "columns")
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width  Class       Type  \
# 0             5.1          3.5           1.4          0.2      0     Setosa
# 1             4.9          3.0           1.4          0.2      0     Setosa
# 2             4.7          3.2           1.3          0.2      0     Setosa
# 3             4.6          3.1           1.5          0.2      0     Setosa
# 4             5.0          3.6           1.4          0.2      0     Setosa
# ..            ...          ...           ...          ...    ...        ...
# 145           6.7          3.0           5.2          2.3      2  Virginica
# 146           6.3          2.5           5.0          1.9      2  Virginica
# 147           6.5          3.0           5.2          2.0      2  Virginica
# 148           6.2          3.4           5.4          2.3      2  Virginica
# 149           5.9          3.0           5.1          1.8      2  Virginica
#
#     Another_flower
# 0              NaN
# ...

# %%
df1.dropna(subset=["Another_flower", "Class"])
# Out:
#      Sepal_length  Sepal_width  Petal_length  Petal_width  Class       Type  \
# 0             5.1          3.5           1.4          0.2      0     Setosa
# 1             4.9          3.0           1.4          0.2      0     Setosa
# 2             4.7          3.2           1.3          0.2      0     Setosa
# 3             4.6          3.1           1.5          0.2      0     Setosa
# 4             5.0          3.6           1.4          0.2      0     Setosa
# ..            ...          ...           ...          ...    ...        ...
# 145           6.7          3.0           5.2          2.3      2  Virginica
# 146           6.3          2.5           5.0          1.9      2  Virginica
# 147           6.5          3.0           5.2          2.0      2  Virginica
# 148           6.2          3.4           5.4          2.3      2  Virginica
# 149           5.9          3.0           5.1          1.8      2  Virginica
#
#     Another_flower
# 0              NaN
# ...

# %%
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length     nothing  Petal_width  Class  \
# 0           5.1          3.5           1.4  no_flowers          0.2      0
# 1           4.9          3.0           1.4  no_flowers          0.2      0
# 2           4.7          3.2           1.3  no_flowers          0.2      0
# 3           4.6          3.1           1.5  no_flowers          0.2      0
# 4           5.0          3.6           1.4  no_flowers          0.2      0
#
#      Type Flowers   nothing-1 Another_flower  Sepal in Kg
# 0  Setosa    ROSE  no_flowers           IRIS       5100.0
# 1  Setosa    ROSE  no_flowers           IRIS       4900.0
# 2  Setosa    ROSE  no_flowers           IRIS       4700.0
# 3  Setosa    ROSE  no_flowers           IRIS       4600.0
# 4  Setosa    ROSE  no_flowers           IRIS       5000.0

# %% [markdown]
# # .astype()

# %%
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    Sepal_length  Sepal_width  Petal_length  Petal_width  Class    Type
# 0           5.1          3.5           1.4          0.2      0  Setosa
# 1           4.9          3.0           1.4          0.2      0  Setosa
# 2           4.7          3.2           1.3          0.2      0  Setosa
# 3           4.6          3.1           1.5          0.2      0  Setosa
# 4           5.0          3.6           1.4          0.2      0  Setosa

# %%
df.dtypes
# Out:
# Sepal_length    float64
# Sepal_width     float64
# Petal_length    float64
# Petal_width     float64
# Class             int64
# Type             object
# dtype: object

# %%
df["Petal_length"]= df["Petal_length"].astype("str")
df.head()
# Out:
#    Sepal_length  Sepal_width Petal_length  Petal_width  Class    Type
# 0           5.1          3.5          1.4          0.2      0  Setosa
# 1           4.9          3.0          1.4          0.2      0  Setosa
# 2           4.7          3.2          1.3          0.2      0  Setosa
# 3           4.6          3.1          1.5          0.2      0  Setosa
# 4           5.0          3.6          1.4          0.2      0  Setosa

# %%
df.dtypes
# Out:
# Sepal_length    float64
# Sepal_width     float64
# Petal_length     object
# Petal_width     float64
# Class             int64
# Type             object
# dtype: object

# %% [markdown]
# # CATEGORY

# %%
#converting float/int/str to category we can reduce the memory usage 

df["Petal_length"]= df["Petal_length"].astype("category")
df.head()
df.dtypes
# Out:
# Sepal_length     float64
# Sepal_width      float64
# Petal_length    category
# Petal_width      float64
# Class              int64
# Type              object
# dtype: object

# %%
df["Petal_length"].nunique() # check the number of unique value before converting into category
# Out:
# 43
